# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns
import os
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Dense
from tensorflow.python.keras.wrappers.scikit_learn import KerasRegressor
from tensorflow.keras import regularizers
import random

# %%
sns.set_style("whitegrid")

# %%
dir_gdl = '../data/processed/2016-2019_3std_preprocessed.csv'
df = pd.read_csv(dir_gdl)
df_data = df[df['PARAM']=='PM10'].fillna(-1)
df_data.drop(columns=['Unnamed: 0'], inplace=True)
df_data = df_data[df_data.CEN != -1] #Elimina valores negativos en la columna de salida
print(df_data.shape)
df_data.head(5)
# Out:
#                       FECHA   HORA PARAM    AGU     ATM     CEN     LDO  \
# 4       2016-01-01 00:00:00  00:00  PM10  49.92  146.95   86.12  174.04
# 13      2016-01-01 01:00:00  01:00  PM10  52.80   -1.00   46.49  115.27
# 22      2016-01-01 02:00:00  02:00  PM10  52.71  113.44   63.93   99.00
# 31      2016-01-01 03:00:00  03:00  PM10  51.24   73.30   60.75   83.65
# 40      2016-01-01 04:00:00  04:00  PM10  58.84   52.55  108.09   49.70
# ...                     ...    ...   ...    ...     ...     ...     ...
# 315535  2019-12-31 19:00:00  19:00  PM10  -1.00   18.10   22.27   84.00
# 315544  2019-12-31 20:00:00  20:00  PM10  -1.00   -1.00   27.51   84.40
# 315553  2019-12-31 21:00:00  21:00  PM10  -1.00   -1.00   28.60   75.30
# 315562  2019-12-31 22:00:00  22:00  PM10  -1.00   -1.00   50.43  125.60
# 315571  2019-12-31 23:00:00  23:00  PM10  -1.00   58.20   66.09  141.50
#
#          LPIN     MIR     OBL     SFE     TLA    VAL
# 4        -1.0   69.75  197.67  115.54  143.40  17.08
# 13       -1.0   68.99  138.09   84.24  100.46  29.15
# 22       -1.0  117.70   98.79  135.39   82.05  30.89
# 31       -1.0  160.30   97.94  117.60  114.74  38.74
# 40       -1.0  180.89  134.39  164.68  118.83  51.48
# ...       ...     ...     ...     ...     ...    ...
# 315535   46.2   -1.00   -1.00   -1.00   12.68  16.20
# 315544   57.4   -1.00   -1.00   -1.00   50.31  14.00
# 315553  151.5   -1.00   -1.00   -1.00    6.86  22.90
# 315562  174.2   -1.00   -1.00   -1.00  113.16  32.10
# 315571  144.3   -1.00   -1.00   -1.00  113.39  39.00
#
# [27504 rows x 13 columns]

# %%
X,Y = df_data[['AGU','ATM','LDO','LPIN','MIR','OBL','SFE','TLA','VAL']].to_numpy(), df_data["CEN"].to_numpy()   #separate data into input and output features

Y=np.reshape(Y, (-1,1))

X_std = (X - np.nanmin(np.where(X>=0, X, np.nan),axis=0)) / (X.max(axis=0) - np.nanmin(np.where(X>=0, X, np.nan),axis=0))
xscale = X_std * (1 - 0) + 0
xscale[X==-1]=-1

scaler_y = MinMaxScaler()
scaler_y.fit(Y)
yscale=scaler_y.transform(Y)

X_train,X_test,Y_train,Y_test = train_test_split(X, Y, test_size = 0.2) #split

# %% [markdown]
# ## Testing code configurations

# %% [markdown]
# #### Creating layers

# %%
def neuron_layers(nx,nh,ny,hl,act,r, seed=None):
    
    tf.keras.regularizers.l1(l1=r)
    
    initializer = tf.keras.initializers.RandomNormal(seed=seed)
    
    model = Sequential()
    
    for i in range(1, 3+hl):
        
        if i == 1:
            model.add(Dense(nx, input_dim=9, kernel_initializer=initializer,
                            activation=act,kernel_regularizer='l1'))
            
        elif i == (2+hl):
            model.add(Dense(ny, activation='linear'))
            
        else:
            model.add(Dense(nh, activation=act))
            
    return model

# %% [markdown]
# ## Previous model

# %%
nn = pd.read_csv('../data/nn_models_vRegL1.csv')
print(nn.shape)
nn.head(5)
# Out:
#        Unnamed: 0              model1              model2              model3  \
# 0          epochs                  50                  50                  50
# 1  hidden_neurons                   5                   5                   5
# 2   hidden_layers                   1                   1                   1
# 3      activation                relu                relu                relu
# 4        r2_train   0.767177493139766  0.7731823564405294  0.7780088849659437
# 5         r2_test  0.7729807985170473  0.7863405567465785  0.7873429586392116
#
#                model4              model5              model6  \
# 0                  50                  50                  50
# 1                   5                   5                   5
# 2                   1                   1                   1
# 3                relu                relu                relu
# 4  0.7639709965842975  0.7443761739638564  0.7485955263466167
# 5  0.7615581295732288  0.7477935499990529  0.7549564420063439
#
#                model7              model8              model9  ...  \
# 0                  50                  50                  50  ...
# 1                   5                   5                   5  ...
# 2                   1                   2                   2  ...
# 3                relu                relu                relu  ...
# 4     0.7447819158669  0.7743928212944475  0.7605766571428063  ...
# 5  0.7505409061706845  0.7777078330199059  0.7660937078405978  ...
#
#             model1251           model1252           model1253  \
# 0                 200                 200                 200
# 1                 100                 100                 100
# 2                   9                   9                   9
# 3                relu                relu                relu
# 4  0.8743118756089514  0.8379421373019184  0.8817088906088432
# 5  0.7521476346579116  0.7835933074432411  0.7780620619541616
#
#             model1254           model1255           model1256  \
# 0                 200                 200                 200
# 1                 100                 100                 100
# 2                  10                  10                  10
# 3                relu                relu                relu
# 4  0.8623310446962773  0.8813360701690305  0.8386252635530339
# 5   0.760399305220298   0.764375972529673  0.7503914483105985
#
#             model1257           model1258           model1259  \
# 0                 200                 200                 200
# 1                 100                 100                 100
# 2                  10                  10                  10
# 3                relu                relu                relu
# 4   0.879685679252549  0.8665445848303253  0.8740642065917972
# 5  0.7658356805633514     0.7920441935959  0.7658092798421967
#
#             model1260
# 0                 200
# 1                 100
# 2                  10
# 3                relu
# 4   0.881184186776162
# 5  0.7659200814292269
#
# [6 rows x 1261 columns]

# %%
nn_80 = list(nn.iloc[5,1:].astype('float')>=0.8)
indices = [i for i, x in enumerate(nn_80) if x == True]

# %% [markdown]
# ## Iteration over one model

# %%
i = 789
nh = int(nn.iloc[:,i+1]['hidden_neurons'])
hl = int(nn.iloc[:,i+1]['hidden_layers'])
e = int(nn.iloc[:,i+1]['epochs'])
a = nn.iloc[:,i+1]['activation']

models = {}
r = 0.01

for c in range(100):
    
    X,Y = df_data[['AGU','ATM','LDO','LPIN','MIR','OBL','SFE','TLA','VAL']].to_numpy(), df_data["CEN"].to_numpy()   #separate data into input and output features

    Y=np.reshape(Y, (-1,1))

    X_std = (X - np.nanmin(np.where(X>=0, X, np.nan),axis=0)) / (X.max(axis=0) - np.nanmin(np.where(X>=0, X, np.nan),axis=0))
    xscale = X_std * (1 - 0) + 0
    xscale[X==-1]=-1

    scaler_y = MinMaxScaler()
    scaler_y.fit(Y)
    yscale=scaler_y.transform(Y)

    X_train,X_test,Y_train,Y_test = train_test_split(X, Y, test_size = 0.2) #split
        
    model = neuron_layers(10,nh,1,hl,a,r, 1)

    model.compile(loss='mse', optimizer='adam', metrics=['mse','mae'])

    history = model.fit(X_train, Y_train, epochs=e, batch_size=50,  verbose=0, validation_split=0.2)

    #statistics for train
    y_hat= model.predict(X_train)
    acc_train = r2_score(Y_train, y_hat)
    mse_train = mean_squared_error(Y_train, y_hat)
    mae_train = mean_absolute_error(Y_train, y_hat)
    rmse_train = mean_squared_error(Y_train, y_hat, squared=False)

    res_train = Y_train - y_hat
    std_res_train = round(res_train.std(),3)

    num_train = ((y_hat - Y_train)**2).sum()
    den_train = ((abs(y_hat - Y_train.mean()) + 
            abs(Y_train - Y_train.mean()))**2).sum()
    ia_train = round(1 - (num_train / den_train),3)

    #accuracy for test
    y_hat = model.predict(X_test)
    acc_test = r2_score(Y_test, y_hat)
    mse_test = mean_squared_error(Y_test, y_hat)
    mae_test = mean_absolute_error(Y_test, y_hat)
    rmse_test = mean_squared_error(Y_test, y_hat, squared=False)

    res_test = Y_test - y_hat
    std_res_test = round(res_test.std(),3)

    num_test = ((y_hat - Y_test)**2).sum()
    den_test = ((abs(y_hat - Y_test.mean()) + 
            abs(Y_test - Y_test.mean()))**2).sum()
    ia_test = round(1 - (num_test / den_test),3)

    models['model'+str(i+1)+'-'+str(r)] = [e, nh, hl, a, r, 
                                           acc_train, mse_train, mae_train, rmse_train, std_res_train, ia_train
                                           acc_test, mse_test, mae_test, rmse_test, std_res_test, ia_test]

    print ('\n*For model',str(i+1),'settings are:','-epochs:',str(e),'-hidden neurons:',str(nh),'-hidden layers:',str(hl),'-activation:',a,
           '-regularization cost:',r,
           '\nAccuracy for training is:', str(acc_train),'Accuracy for test is:',str(acc_test),
          '\nMSE for training is:', str(mse_train),'MSE for test is:',str(mse_test),
           '\nMAE for training is:', str(mae_train),'MAE for test is:',str(mae_test),
           '\nRMSE for training is:', str(rmse_train),'RMSE for test is:',str(rmse_test))

# %% [markdown]
# ## Testing for different seeds in train split

# %%
i = 789
nh = int(nn.iloc[:,i+1]['hidden_neurons'])
hl = int(nn.iloc[:,i+1]['hidden_layers'])
e = int(nn.iloc[:,i+1]['epochs'])
a = nn.iloc[:,i+1]['activation']

models = {}
r = 0.01

rndm = random.sample(range(100), 50)

for rnd_ts in rndm:
    
    X_train,X_test,Y_train,Y_test = train_test_split(X, Y, test_size = 0.2, random_state=rnd_ts) #split
    
    model = neuron_layers(10,nh,1,hl,a,r,1)

    model.compile(loss='mse', optimizer='adam', metrics=['mse','mae'])

    history = model.fit(X_train, Y_train, epochs=e, batch_size=50,  verbose=0, validation_split=0.2)

    #statistics for train
    y_hat= model.predict(X_train)
    acc_train = r2_score(Y_train, y_hat)
    mse_train = mean_squared_error(Y_train, y_hat)
    mae_train = mean_absolute_error(Y_train, y_hat)
    rmse_train = mean_squared_error(Y_train, y_hat, squared=False)

    res_train = Y_train - y_hat
    std_res_train = round(res_train.std(),3)

    num_train = ((y_hat - Y_train)**2).sum()
    den_train = ((abs(y_hat - Y_train.mean()) + 
            abs(Y_train - Y_train.mean()))**2).sum()
    ia_train = round(1 - (num_train / den_train),3)

    #accuracy for test
    y_hat = model.predict(X_test)
    acc_test = r2_score(Y_test, y_hat)
    mse_test = mean_squared_error(Y_test, y_hat)
    mae_test = mean_absolute_error(Y_test, y_hat)
    rmse_test = mean_squared_error(Y_test, y_hat, squared=False)

    res_test = Y_test - y_hat
    std_res_test = round(res_test.std(),3)

    num_test = ((y_hat - Y_test)**2).sum()
    den_test = ((abs(y_hat - Y_test.mean()) + 
            abs(Y_test - Y_test.mean()))**2).sum()
    ia_test = round(1 - (num_test / den_test),3)

    models['model'+str(i+1)+'-'+str(r)] = [e, nh, hl, a, r, rnd_ts,
                                           acc_train, mse_train, mae_train, rmse_train, std_res_train, ia_train
                                           acc_test, mse_test, mae_test, rmse_test, std_res_test, ia_test]

    print ('\n*For model',str(i+1),'settings are:','-epochs:',str(e),'-hidden neurons:',str(nh),'-hidden layers:',str(hl),'-activation:',a,
           '-regularization cost:',r,'-random_state:',rnd_ts,
           '\nAccuracy for training is:', str(acc_train),'Accuracy for test is:',str(acc_test))
# Out:
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 1
# Accuracy for training is: 0.8411286125958266 Accuracy for test is: 0.7825824620634125
# MSE for training is: 103.30344859207045 MSE for test is: 152.25608871856898
# MAE for training is: 6.844224496615397 MAE for test is: 7.780826673561433
# RMSE for training is: 10.163830409450487 RMSE for test is: 12.33920940411374
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 2
# Accuracy for training is: 0.8378729978775774 Accuracy for test is: 0.7866936488675909
# MSE for training is: 104.30724899176036 MSE for test is: 155.28305651128778
# MAE for training is: 6.949140598170428 MAE for test is: 7.874360911856996
# RMSE for training is: 10.213092038739314 RMSE for test is: 12.46126223587674
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 3
# Accuracy for training is: 0.8319507205717828 Accuracy for test is: 0.7816677188019685
# MSE for training is: 110.82052539073557 MSE for test is: 144.9193147533735
# MAE for training is: 6.964852873764889 MAE for test is: 7.657719747709417
# RMSE for training is: 10.527132819088756 RMSE for test is: 12.038243840086206
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 4
# Accuracy for training is: 0.8440850229353463 Accuracy for test is: 0.7684818842802696
# MSE for training is: 102.90428776287175 MSE for test is: 153.16214842431359
# MAE for training is: 6.952894995961976 MAE for test is: 7.894153346067082
# RMSE for training is: 10.144175065665603 RMSE for test is: 12.375869602751703
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 5
# Accuracy for training is: 0.84976126568804 Accuracy for test is: 0.7820362773656184
# MSE for training is: 100.83118393355622 MSE for test is: 134.4392051774936
# MAE for training is: 6.7794410751000305 MAE for test is: 7.683650653189344
# RMSE for training is: 10.041473195381055 RMSE for test is: 11.594792157580644
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 6
# Accuracy for training is: 0.837447717683147 Accuracy for test is: 0.7873485100046809
# MSE for training is: 107.80147291686708 MSE for test is: 137.97714493713505
# MAE for training is: 6.96913090339572 MAE for test is: 7.558234557753541
# RMSE for training is: 10.382748813145152 RMSE for test is: 11.746367308114243
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 7
# Accuracy for training is: 0.8495374449054216 Accuracy for test is: 0.7589222310971835
# MSE for training is: 97.5430404265795 MSE for test is: 170.70669138107775
# MAE for training is: 6.65862875568215 MAE for test is: 7.75403888369924
# RMSE for training is: 9.876388025314695 RMSE for test is: 13.065477082031018
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 8
# Accuracy for training is: 0.8421423256096928 Accuracy for test is: 0.7980463724419762
# MSE for training is: 104.37877657368475 MSE for test is: 132.60729585540358
# MAE for training is: 6.819219645574343 MAE for test is: 7.54470770450142
# RMSE for training is: 10.216593198012964 RMSE for test is: 11.515524124216126
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 9
# Accuracy for training is: 0.8277497161535297 Accuracy for test is: 0.7736042375047967
# MSE for training is: 115.6493144501466 MSE for test is: 139.40023203169912
# MAE for training is: 7.040523093726523 MAE for test is: 7.4131190458442315
# RMSE for training is: 10.754037123338685 RMSE for test is: 11.806787540719919
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 10
# Accuracy for training is: 0.8235167319832764 Accuracy for test is: 0.7749110073832746
# MSE for training is: 115.709781436659 MSE for test is: 152.81160540290685
# MAE for training is: 7.076448884195952 MAE for test is: 7.712412775418819
# RMSE for training is: 10.756848118136604 RMSE for test is: 12.361699130900528
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 11
# Accuracy for training is: 0.8369754888243733 Accuracy for test is: 0.7763049231208549
# MSE for training is: 107.27267904464277 MSE for test is: 149.7646520945064
# MAE for training is: 6.858557866697185 MAE for test is: 7.6647837904743055
# RMSE for training is: 10.357252485318815 RMSE for test is: 12.237836904228883
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 12
# Accuracy for training is: 0.8257039434045228 Accuracy for test is: 0.7734873615163043
# MSE for training is: 116.75335358498039 MSE for test is: 140.86329273077195
# MAE for training is: 7.395797000536967 MAE for test is: 8.059680234212655
# RMSE for training is: 10.805246576778357 RMSE for test is: 11.86858427660064
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 13
# Accuracy for training is: 0.8238028073210721 Accuracy for test is: 0.7838564327662499
# MSE for training is: 116.32557207713582 MSE for test is: 142.81060056305682
# MAE for training is: 7.106253784939662 MAE for test is: 7.706187924712902
# RMSE for training is: 10.785433328204101 RMSE for test is: 11.950338930886305
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 14
# Accuracy for training is: 0.8297523027565383 Accuracy for test is: 0.7720131572289417
# MSE for training is: 113.4091384595462 MSE for test is: 145.21619905783896
# MAE for training is: 7.317076659790868 MAE for test is: 7.9636187147517745
# RMSE for training is: 10.649372679155622 RMSE for test is: 12.050568412230145
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 15
# Accuracy for training is: 0.8310095820720554 Accuracy for test is: 0.7818648043764699
# MSE for training is: 110.46557854336358 MSE for test is: 149.81414860313774
# MAE for training is: 7.127998770121352 MAE for test is: 7.631318763212125
# RMSE for training is: 10.510260631562073 RMSE for test is: 12.239859010754076
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 16
# Accuracy for training is: 0.8362523225931472 Accuracy for test is: 0.7827434307441506
# MSE for training is: 108.247374886639 MSE for test is: 142.8042554474837
# MAE for training is: 6.959828195792733 MAE for test is: 7.584770684284159
# RMSE for training is: 10.40419986768031 RMSE for test is: 11.950073449459786
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 17
# Accuracy for training is: 0.8221588188781505 Accuracy for test is: 0.7745665288997218
# MSE for training is: 115.90833601312502 MSE for test is: 156.56986245415365
# MAE for training is: 7.390072418277558 MAE for test is: 8.231066894822156
# RMSE for training is: 10.76607337951609 RMSE for test is: 12.512787956892486
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 18
# Accuracy for training is: 0.8381321599884024 Accuracy for test is: 0.7888790188051761
# MSE for training is: 105.95175990800716 MSE for test is: 144.20983501847437
# MAE for training is: 6.94768354287048 MAE for test is: 7.758662562932866
# RMSE for training is: 10.293287128415644 RMSE for test is: 12.008739942994618
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 19
# Accuracy for training is: 0.8453050297197143 Accuracy for test is: 0.7805778747414938
# MSE for training is: 102.15015604823712 MSE for test is: 144.86177279585627
# MAE for training is: 6.8447978132413745 MAE for test is: 7.566591969124081
# RMSE for training is: 10.106936036615505 RMSE for test is: 12.035853638020706
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 20
# Accuracy for training is: 0.8415973619746194 Accuracy for test is: 0.7899460628928643
# MSE for training is: 105.5591753244718 MSE for test is: 133.5011738661216
# MAE for training is: 6.915828928826652 MAE for test is: 7.5812814564229
# RMSE for training is: 10.274199497988727 RMSE for test is: 11.554270806334841
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 21
# Accuracy for training is: 0.8217171469800169 Accuracy for test is: 0.786983743643925
# MSE for training is: 116.4416241567535 MSE for test is: 146.7786771872247
# MAE for training is: 7.093696601098513 MAE for test is: 7.631675103885698
# RMSE for training is: 10.790812024901253 RMSE for test is: 12.115225015955119
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 22
# Accuracy for training is: 0.8321181578268186 Accuracy for test is: 0.7825371889849476
# MSE for training is: 110.37059788785146 MSE for test is: 146.09332137132645
# MAE for training is: 7.0284571465269705 MAE for test is: 7.695125611219769
# RMSE for training is: 10.505741186982071 RMSE for test is: 12.086907022531713
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 23
# Accuracy for training is: 0.8338237111040636 Accuracy for test is: 0.7981755255153519
# MSE for training is: 110.4181650015924 MSE for test is: 129.91668925969358
# MAE for training is: 6.920875033801292 MAE for test is: 7.578679028912212
# RMSE for training is: 10.508004805936872 RMSE for test is: 11.398100247834881
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 24
# Accuracy for training is: 0.8157008924051805 Accuracy for test is: 0.7737546161886435
# MSE for training is: 122.89778595173367 MSE for test is: 143.47165067579203
# MAE for training is: 7.592825371909422 MAE for test is: 7.991925735225722
# RMSE for training is: 11.085927383477381 RMSE for test is: 11.977965214333862
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 25
# Accuracy for training is: 0.8483237827396426 Accuracy for test is: 0.8010337609496818
# MSE for training is: 99.59225144936863 MSE for test is: 134.3234715256365
# MAE for training is: 6.71865845856274 MAE for test is: 7.475068543617041
# RMSE for training is: 9.979591747630192 RMSE for test is: 11.589800322940707
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 26
# Accuracy for training is: 0.8396315129389129 Accuracy for test is: 0.8057747784784641
# MSE for training is: 105.17076438474102 MSE for test is: 131.749881086981
# MAE for training is: 6.841487298323763 MAE for test is: 7.62746928143601
# RMSE for training is: 10.255279829665353 RMSE for test is: 11.478235103315361
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 27
# Accuracy for training is: 0.8260438720539628 Accuracy for test is: 0.7783558896087519
# MSE for training is: 115.23139520409813 MSE for test is: 144.47457083242548
# MAE for training is: 7.367249063397246 MAE for test is: 7.98431952067675
# RMSE for training is: 10.734588730086408 RMSE for test is: 12.019757519701697
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 28
# Accuracy for training is: 0.8405294467976486 Accuracy for test is: 0.7898001877569159
# MSE for training is: 102.93078336755983 MSE for test is: 151.2588705886125
# MAE for training is: 6.79117902954846 MAE for test is: 7.791831387445463
# RMSE for training is: 10.145480933280583 RMSE for test is: 12.298734511672837
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 29
# Accuracy for training is: 0.8202821700288309 Accuracy for test is: 0.7869643991921096
# MSE for training is: 120.39313874626414 MSE for test is: 132.43753244310076
# MAE for training is: 7.185382307994628 MAE for test is: 7.592417226878757
# RMSE for training is: 10.972380723720088 RMSE for test is: 11.508150696054548
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 30
# Accuracy for training is: 0.8334648636173758 Accuracy for test is: 0.7883513462419224
# MSE for training is: 107.90554673121248 MSE for test is: 150.1788238605941
# MAE for training is: 6.983836016400676 MAE for test is: 7.762361953189603
# RMSE for training is: 10.387759466372549 RMSE for test is: 12.254746992924582
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 31
# Accuracy for training is: 0.831994716507237 Accuracy for test is: 0.7853493283849218
# MSE for training is: 109.83723833208225 MSE for test is: 147.33617891916933
# MAE for training is: 7.133315133505722 MAE for test is: 7.9420600776069055
# RMSE for training is: 10.480326251223396 RMSE for test is: 12.138211520614119
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 32
# Accuracy for training is: 0.8210164791954262 Accuracy for test is: 0.7775062008574012
# MSE for training is: 116.06182981167812 MSE for test is: 157.42674454446342
# MAE for training is: 7.059915507457627 MAE for test is: 7.823023893699237
# RMSE for training is: 10.773199608829223 RMSE for test is: 12.54698149135733
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 33
# Accuracy for training is: 0.8311463997646384 Accuracy for test is: 0.7826274680599686
# MSE for training is: 111.04871167777338 MSE for test is: 145.8359374851621
# MAE for training is: 7.256752211424543 MAE for test is: 8.064548141966299
# RMSE for training is: 10.53796525320583 RMSE for test is: 12.076255110139158
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 34
# Accuracy for training is: 0.8408182326694986 Accuracy for test is: 0.7793402699436928
# MSE for training is: 105.2595206669977 MSE for test is: 144.8513361235525
# MAE for training is: 6.966297976191692 MAE for test is: 7.8808136949742025
# RMSE for training is: 10.259606262766505 RMSE for test is: 12.03542006427497
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 35
# Accuracy for training is: 0.8463844883739479 Accuracy for test is: 0.7789964263474582
# MSE for training is: 101.68858474759243 MSE for test is: 144.44225981297302
# MAE for training is: 6.8660006255389225 MAE for test is: 7.649260611659809
# RMSE for training is: 10.084075800369234 RMSE for test is: 12.018413365040038
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 36
# Accuracy for training is: 0.846344632744229 Accuracy for test is: 0.7747309401188438
# MSE for training is: 103.41387446815943 MSE for test is: 137.21787928674902
# MAE for training is: 6.823562694366653 MAE for test is: 7.658136367835992
# RMSE for training is: 10.169261254789328 RMSE for test is: 11.714003555008382
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 37
# Accuracy for training is: 0.8028884962660241 Accuracy for test is: 0.7507308182771697
# MSE for training is: 132.14717382123598 MSE for test is: 154.46408315522822
# MAE for training is: 7.710577579382782 MAE for test is: 8.077428860892342
# RMSE for training is: 11.495528427229258 RMSE for test is: 12.428358023296088
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 38
# Accuracy for training is: 0.835023119454844 Accuracy for test is: 0.7676046768984965
# MSE for training is: 109.52937589198669 MSE for test is: 150.05914901298098
# MAE for training is: 7.085721623932032 MAE for test is: 7.739578146467293
# RMSE for training is: 10.465628308514816 RMSE for test is: 12.249863224256057
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 39
# Accuracy for training is: 0.8292394693216798 Accuracy for test is: 0.77005932131593
# MSE for training is: 111.95519408403636 MSE for test is: 156.12808775428707
# MAE for training is: 7.184623973782895 MAE for test is: 7.959858107505288
# RMSE for training is: 10.580888151948132 RMSE for test is: 12.495122558594096
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 40
# Accuracy for training is: 0.8378027060420282 Accuracy for test is: 0.7913981628330649
# MSE for training is: 106.6773720288146 MSE for test is: 139.86940655222358
# MAE for training is: 6.944441467405649 MAE for test is: 7.618855856942428
# RMSE for training is: 10.328473847999742 RMSE for test is: 11.82663969825003
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 41
# Accuracy for training is: 0.8508955958841885 Accuracy for test is: 0.7637031913093018
# MSE for training is: 99.37549524354473 MSE for test is: 150.19904334741818
# MAE for training is: 6.676767123767128 MAE for test is: 7.735984560322966
# RMSE for training is: 9.968725858581163 RMSE for test is: 12.255571930653346
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 42
# Accuracy for training is: 0.8290309466326904 Accuracy for test is: 0.7928968735515125
# MSE for training is: 114.04851809643262 MSE for test is: 131.15442608612142
# MAE for training is: 7.213421398574601 MAE for test is: 7.7272492498832275
# RMSE for training is: 10.679350078372401 RMSE for test is: 11.45226729019723
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 43
# Accuracy for training is: 0.8330130899075439 Accuracy for test is: 0.7865114332764507
# MSE for training is: 109.48559827558836 MSE for test is: 144.9308287180029
# MAE for training is: 6.967821765002459 MAE for test is: 7.729566491549503
# RMSE for training is: 10.463536604589692 RMSE for test is: 12.038722055019084
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 44
# Accuracy for training is: 0.8392705892641843 Accuracy for test is: 0.7828512052679513
# MSE for training is: 104.9482387988441 MSE for test is: 149.77954364100046
# MAE for training is: 6.842794713266209 MAE for test is: 7.64614990672604
# RMSE for training is: 10.244424766615454 RMSE for test is: 12.238445311435617
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 45
# Accuracy for training is: 0.8188881226404168 Accuracy for test is: 0.7772906908120099
# MSE for training is: 120.78061546172361 MSE for test is: 141.0309346874182
# MAE for training is: 7.053601298193214 MAE for test is: 7.528558658786393
# RMSE for training is: 10.990023451372778 RMSE for test is: 11.875644600922437
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 46
# Accuracy for training is: 0.8257469532376969 Accuracy for test is: 0.7928877936024498
# MSE for training is: 116.21187564716719 MSE for test is: 131.2392766200394
# MAE for training is: 7.0901740515054055 MAE for test is: 7.522093071753796
# RMSE for training is: 10.780161206919272 RMSE for test is: 11.455971221159706
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 47
# Accuracy for training is: 0.8252200210249252 Accuracy for test is: 0.7803486383995119
# MSE for training is: 114.85809437779825 MSE for test is: 147.79916307849976
# MAE for training is: 7.13567300569782 MAE for test is: 7.777740737924748
# RMSE for training is: 10.71718686866093 RMSE for test is: 12.15726791176783
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 48
# Accuracy for training is: 0.8377673179274016 Accuracy for test is: 0.7795208441779464
# MSE for training is: 107.01970998722699 MSE for test is: 146.15193235541693
# MAE for training is: 7.026480843907956 MAE for test is: 7.781868013583233
# RMSE for training is: 10.345033107111208 RMSE for test is: 12.089331344429969
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 49
# Accuracy for training is: 0.845797321995528 Accuracy for test is: 0.7819565280173338
# MSE for training is: 103.14881201193066 MSE for test is: 136.4185952764883
# MAE for training is: 6.798331714096902 MAE for test is: 7.612564482698439
# RMSE for training is: 10.156220360544106 RMSE for test is: 11.679837125426378
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 50
# Accuracy for training is: 0.8211324496189849 Accuracy for test is: 0.7884498491960065
# MSE for training is: 117.23025418096704 MSE for test is: 143.83235827335824
# MAE for training is: 7.121720149747016 MAE for test is: 7.795349696377281
# RMSE for training is: 10.827292098256471 RMSE for test is: 11.993012893904444
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 51
# Accuracy for training is: 0.8175448282877614 Accuracy for test is: 0.7794881167739237
# MSE for training is: 120.32791438982863 MSE for test is: 146.33018532383286
# MAE for training is: 7.0526257130852095 MAE for test is: 7.629858398967994
# RMSE for training is: 10.969408114835943 RMSE for test is: 12.096701423273737
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 52
# Accuracy for training is: 0.8234929460944842 Accuracy for test is: 0.7518197191029471
# MSE for training is: 117.01047857261783 MSE for test is: 161.27222055528617
# MAE for training is: 7.332027927623198 MAE for test is: 8.081568563729064
# RMSE for training is: 10.817138187737912 RMSE for test is: 12.699300002570464
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 53
# Accuracy for training is: 0.8377741814329196 Accuracy for test is: 0.7656960268496378
# MSE for training is: 105.61575292656089 MSE for test is: 163.40324905825236
# MAE for training is: 6.97586306986814 MAE for test is: 7.721156156657283
# RMSE for training is: 10.276952511642783 RMSE for test is: 12.782928031489982
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 54
# Accuracy for training is: 0.8336918340366976 Accuracy for test is: 0.7704997261163542
# MSE for training is: 109.38942377089212 MSE for test is: 153.8913709202921
# MAE for training is: 6.871610045084913 MAE for test is: 7.817489026516399
# RMSE for training is: 10.458939897087664 RMSE for test is: 12.40529608353997
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 55
# Accuracy for training is: 0.8241474843297584 Accuracy for test is: 0.7822490557497176
# MSE for training is: 116.9659471817921 MSE for test is: 139.5739910030005
# MAE for training is: 7.143117007045385 MAE for test is: 7.728664847363387
# RMSE for training is: 10.815079619762034 RMSE for test is: 11.814143684711157
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 56
# Accuracy for training is: 0.8416388599467823 Accuracy for test is: 0.7743539679417019
# MSE for training is: 104.47107395048768 MSE for test is: 149.54924324828607
# MAE for training is: 6.8920512269572365 MAE for test is: 7.802368224835184
# RMSE for training is: 10.22110923288112 RMSE for test is: 12.229032801014398
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 57
# Accuracy for training is: 0.8402674623904236 Accuracy for test is: 0.7758179800159754
# MSE for training is: 104.01939586672033 MSE for test is: 156.18182082340093
# MAE for training is: 6.923061439163385 MAE for test is: 7.819266005786326
# RMSE for training is: 10.198989943456182 RMSE for test is: 12.497272535373506
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 58
# Accuracy for training is: 0.8166650748949347 Accuracy for test is: 0.7927803299056583
# MSE for training is: 120.61372823751212 MSE for test is: 138.8363533851821
# MAE for training is: 7.229807752225061 MAE for test is: 7.673363801480814
# RMSE for training is: 10.982428157630357 RMSE for test is: 11.782883916307675
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 59
# Accuracy for training is: 0.8518436966675621 Accuracy for test is: 0.7716800857709558
# MSE for training is: 98.36791068005859 MSE for test is: 147.44092680151607
# MAE for training is: 6.800983039076304 MAE for test is: 7.779305789165334
# RMSE for training is: 9.91805982438393 RMSE for test is: 12.142525552845918
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 60
# Accuracy for training is: 0.8452676445956622 Accuracy for test is: 0.7797812454093951
# MSE for training is: 101.77899476102806 MSE for test is: 147.63617763111895
# MAE for training is: 6.873844898463303 MAE for test is: 7.84652325816294
# RMSE for training is: 10.088557615488353 RMSE for test is: 12.150562852440991
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 61
# Accuracy for training is: 0.8308373486774772 Accuracy for test is: 0.7891172660955438
# MSE for training is: 112.13478670080802 MSE for test is: 137.07964848962126
# MAE for training is: 6.9989849094523855 MAE for test is: 7.557054605139016
# RMSE for training is: 10.589371402534148 RMSE for test is: 11.708101831194554
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 62
# Accuracy for training is: 0.8485667172376375 Accuracy for test is: 0.7759311362841621
# MSE for training is: 98.19902284039107 MSE for test is: 158.50451110488845
# MAE for training is: 6.775257725647285 MAE for test is: 7.8282764042544155
# RMSE for training is: 9.90954200961836 RMSE for test is: 12.589857469601808
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 63
# Accuracy for training is: 0.8442625856624291 Accuracy for test is: 0.7962000486172173
# MSE for training is: 103.23540261780659 MSE for test is: 132.46071092671954
# MAE for training is: 6.827775739982889 MAE for test is: 7.603453369119279
# RMSE for training is: 10.160482400841339 RMSE for test is: 11.509157698403456
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 64
# Accuracy for training is: 0.8441466482756476 Accuracy for test is: 0.7748266179835832
# MSE for training is: 103.3448085842085 MSE for test is: 146.15370241770896
# MAE for training is: 6.908501451282702 MAE for test is: 7.802146270734964
# RMSE for training is: 10.165864871431673 RMSE for test is: 12.089404551825908
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 65
# Accuracy for training is: 0.8307162353212925 Accuracy for test is: 0.7839545795209295
# MSE for training is: 112.76221585129056 MSE for test is: 137.64172618246587
# MAE for training is: 7.155804111713984 MAE for test is: 7.8047887347772145
# RMSE for training is: 10.618955497189475 RMSE for test is: 11.732081067844096
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 66
# Accuracy for training is: 0.8227169457948296 Accuracy for test is: 0.7798239801321396
# MSE for training is: 115.47795594263056 MSE for test is: 153.25504874314328
# MAE for training is: 7.284014941272511 MAE for test is: 7.723831738681929
# RMSE for training is: 10.746066998796842 RMSE for test is: 12.379622318275436
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 67
# Accuracy for training is: 0.8370538253107292 Accuracy for test is: 0.7965203164555302
# MSE for training is: 104.13515545352186 MSE for test is: 151.62717080114763
# MAE for training is: 6.81398077447693 MAE for test is: 7.636331769727919
# RMSE for training is: 10.204663416963925 RMSE for test is: 12.313698502121433
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 68
# Accuracy for training is: 0.8447430298951114 Accuracy for test is: 0.7929641601142327
# MSE for training is: 101.6108254811033 MSE for test is: 141.5475690260018
# MAE for training is: 6.732112975111573 MAE for test is: 7.682442679589845
# RMSE for training is: 10.08021951552164 RMSE for test is: 11.89737656065411
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 69
# Accuracy for training is: 0.8216526959889711 Accuracy for test is: 0.7751056187552547
# MSE for training is: 118.60294302849027 MSE for test is: 144.25334038731168
# MAE for training is: 7.1134255212961435 MAE for test is: 7.637931636282585
# RMSE for training is: 10.89049783198593 RMSE for test is: 12.010551210802594
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 70
# Accuracy for training is: 0.829111461904261 Accuracy for test is: 0.7740265590092169
# MSE for training is: 112.33560255917166 MSE for test is: 151.88058546619658
# MAE for training is: 7.1225600333339285 MAE for test is: 7.848321395930193
# RMSE for training is: 10.598849114841274 RMSE for test is: 12.323984155547937
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 71
# Accuracy for training is: 0.8372327656974907 Accuracy for test is: 0.7833478997008421
# MSE for training is: 108.76463118220043 MSE for test is: 136.17691586768507
# MAE for training is: 6.908137016968982 MAE for test is: 7.536352821992236
# RMSE for training is: 10.429028295205667 RMSE for test is: 11.66948652973579
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 72
# Accuracy for training is: 0.8223286198446086 Accuracy for test is: 0.7844410495973646
# MSE for training is: 117.44135762696396 MSE for test is: 141.74104859665715
# MAE for training is: 7.132512076372712 MAE for test is: 7.626552356564638
# RMSE for training is: 10.837036385791272 RMSE for test is: 11.905504970250407
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 73
# Accuracy for training is: 0.8344350464146859 Accuracy for test is: 0.7849738157506081
# MSE for training is: 109.47084863256406 MSE for test is: 141.22518580990996
# MAE for training is: 6.889040126197116 MAE for test is: 7.563804768806934
# RMSE for training is: 10.462831769294777 RMSE for test is: 11.883820337328816
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 74
# Accuracy for training is: 0.8390577202265748 Accuracy for test is: 0.7833313244304525
# MSE for training is: 107.45404324436386 MSE for test is: 136.70388744328383
# MAE for training is: 6.882782467762828 MAE for test is: 7.529919292369856
# RMSE for training is: 10.366004208197287 RMSE for test is: 11.692043766736585
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 75
# Accuracy for training is: 0.8350444348260612 Accuracy for test is: 0.7739426192628306
# MSE for training is: 109.23068876879006 MSE for test is: 147.56791337872139
# MAE for training is: 6.911722700912714 MAE for test is: 7.758393163048253
# RMSE for training is: 10.451348657890524 RMSE for test is: 12.147753429285654
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 76
# Accuracy for training is: 0.8260835726762112 Accuracy for test is: 0.7879502823601088
# MSE for training is: 114.20190248401339 MSE for test is: 143.11923127190485
# MAE for training is: 7.249501311286018 MAE for test is: 7.896103464326216
# RMSE for training is: 10.686529019471822 RMSE for test is: 11.96324501428876
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 77
# Accuracy for training is: 0.8331668277566268 Accuracy for test is: 0.7630272588373143
# MSE for training is: 110.00987789653492 MSE for test is: 157.31611147186803
# MAE for training is: 6.896291388016833 MAE for test is: 7.817326418620589
# RMSE for training is: 10.48855938137049 RMSE for test is: 12.542571963990003
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 78
# Accuracy for training is: 0.8340983054629975 Accuracy for test is: 0.7842032763755347
# MSE for training is: 109.49654612092883 MSE for test is: 142.7531088547478
# MAE for training is: 7.048213954220781 MAE for test is: 7.621489549538717
# RMSE for training is: 10.464059734201102 RMSE for test is: 11.947933246162192
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 79
# Accuracy for training is: 0.8339531232324645 Accuracy for test is: 0.7981914925524171
# MSE for training is: 110.37978173256906 MSE for test is: 129.63057575057653
# MAE for training is: 7.009637131476995 MAE for test is: 7.651812163383999
# RMSE for training is: 10.506178264838697 RMSE for test is: 11.385542400367957
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 80
# Accuracy for training is: 0.8387559308068897 Accuracy for test is: 0.7821880730631214
# MSE for training is: 105.52190704776893 MSE for test is: 148.95062989715368
# MAE for training is: 7.0092334031077 MAE for test is: 7.817211886356884
# RMSE for training is: 10.272385655132352 RMSE for test is: 12.204533169980476
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 81
# Accuracy for training is: 0.8137751650460492 Accuracy for test is: 0.7850651252588061
# MSE for training is: 122.6975955500053 MSE for test is: 143.15277601553842
# MAE for training is: 7.434659027377047 MAE for test is: 7.912703560638636
# RMSE for training is: 11.076894670890633 RMSE for test is: 11.964646923981435
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 82
# Accuracy for training is: 0.8338392022215538 Accuracy for test is: 0.8058802352961835
# MSE for training is: 108.22751668447368 MSE for test is: 135.14448197965407
# MAE for training is: 6.939926322081249 MAE for test is: 7.616845293414309
# RMSE for training is: 10.403245488042359 RMSE for test is: 11.625165890414385
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 83
# Accuracy for training is: 0.8340531458011785 Accuracy for test is: 0.7890916319007082
# MSE for training is: 111.13144855262038 MSE for test is: 131.36110992100137
# MAE for training is: 6.954370410688345 MAE for test is: 7.484238492037854
# RMSE for training is: 10.54189017930942 RMSE for test is: 11.461287446050788
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 84
# Accuracy for training is: 0.8451234231956049 Accuracy for test is: 0.7586920076528723
# MSE for training is: 102.85784886061931 MSE for test is: 155.61992697192625
# MAE for training is: 6.979308655683308 MAE for test is: 8.019283393318275
# RMSE for training is: 10.141885863123255 RMSE for test is: 12.474771620030815
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 85
# Accuracy for training is: 0.8272635508630723 Accuracy for test is: 0.7885189547832269
# MSE for training is: 115.19359434661293 MSE for test is: 134.05364690703635
# MAE for training is: 7.296435952227219 MAE for test is: 7.735877025732536
# RMSE for training is: 10.732827882092069 RMSE for test is: 11.57815386437045
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 86
# Accuracy for training is: 0.8374046647557827 Accuracy for test is: 0.7833298696294138
# MSE for training is: 107.86041078641422 MSE for test is: 140.42342165226944
# MAE for training is: 6.923953664332971 MAE for test is: 7.655250554049237
# RMSE for training is: 10.385586684747965 RMSE for test is: 11.8500388882176
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 87
# Accuracy for training is: 0.8229112550763793 Accuracy for test is: 0.7826817489339222
# MSE for training is: 116.09454606611747 MSE for test is: 147.57967397425088
# MAE for training is: 7.090353694733385 MAE for test is: 7.776600459839946
# RMSE for training is: 10.77471791120851 RMSE for test is: 12.14823748427116
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 88
# Accuracy for training is: 0.8209883903565409 Accuracy for test is: 0.781574350503168
# MSE for training is: 116.48008185529794 MSE for test is: 152.6416610484291
# MAE for training is: 7.234354076700168 MAE for test is: 7.723885679650319
# RMSE for training is: 10.792593842783946 RMSE for test is: 12.354823392037181
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 89
# Accuracy for training is: 0.836279085548085 Accuracy for test is: 0.7925108006254631
# MSE for training is: 107.86326950749446 MSE for test is: 138.22322214792118
# MAE for training is: 6.912993344282283 MAE for test is: 7.699258633967076
# RMSE for training is: 10.385724313089312 RMSE for test is: 11.756837251060388
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 90
# Accuracy for training is: 0.8468065866150603 Accuracy for test is: 0.7876455508793454
# MSE for training is: 100.1069585613861 MSE for test is: 146.0345929658135
# MAE for training is: 6.776191476019231 MAE for test is: 7.588026557944727
# RMSE for training is: 10.005346498816825 RMSE for test is: 12.084477355922907
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 91
# Accuracy for training is: 0.8291111026726171 Accuracy for test is: 0.7703073662554948
# MSE for training is: 114.34932002546223 MSE for test is: 143.55061906322362
# MAE for training is: 7.082140780466901 MAE for test is: 7.6851236709354795
# RMSE for training is: 10.693424148768356 RMSE for test is: 11.98126116330095
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 92
# Accuracy for training is: 0.8168707923472968 Accuracy for test is: 0.7548173621086866
# MSE for training is: 120.8200305746274 MSE for test is: 162.4462228438977
# MAE for training is: 7.15238478252705 MAE for test is: 7.96608367332964
# RMSE for training is: 10.991816527518434 RMSE for test is: 12.745439295838244
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 93
# Accuracy for training is: 0.8183781576028201 Accuracy for test is: 0.8024134847518543
# MSE for training is: 118.07371558807877 MSE for test is: 138.5064121668987
# MAE for training is: 7.05715653017567 MAE for test is: 7.514202681380042
# RMSE for training is: 10.866172996417772 RMSE for test is: 11.768874719653477
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 94
# Accuracy for training is: 0.8376567624024653 Accuracy for test is: 0.7699890888062888
# MSE for training is: 107.52509079548484 MSE for test is: 150.02175909550303
# MAE for training is: 7.023901261777427 MAE for test is: 7.749366228352934
# RMSE for training is: 10.369430591671119 RMSE for test is: 12.24833699305759
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 95
# Accuracy for training is: 0.8365412342539134 Accuracy for test is: 0.8048487718084469
# MSE for training is: 108.73321198547475 MSE for test is: 125.04062830326599
# MAE for training is: 7.115341452393847 MAE for test is: 7.60903188443145
# RMSE for training is: 10.42752185255321 RMSE for test is: 11.18215669284177
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 96
# Accuracy for training is: 0.8372993377468418 Accuracy for test is: 0.8040615126237466
# MSE for training is: 106.52760100839062 MSE for test is: 133.73782573563344
# MAE for training is: 6.84366152661242 MAE for test is: 7.60548833490003
# RMSE for training is: 10.321220906869042 RMSE for test is: 11.564507154895683
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 97
# Accuracy for training is: 0.8177164680955407 Accuracy for test is: 0.7762242454165538
# MSE for training is: 118.95529954126229 MSE for test is: 154.6323758555038
# MAE for training is: 7.499076291084941 MAE for test is: 8.196176030986463
# RMSE for training is: 10.906663080028753 RMSE for test is: 12.435126692378482
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 98
# Accuracy for training is: 0.8318082596439544 Accuracy for test is: 0.7423445319501223
# MSE for training is: 110.62450593179783 MSE for test is: 172.79242276362285
# MAE for training is: 6.989084353154958 MAE for test is: 7.807841011717242
# RMSE for training is: 10.517818496808063 RMSE for test is: 13.145053167013927
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 99
# Accuracy for training is: 0.8493332905388065 Accuracy for test is: 0.7436401613822956
# MSE for training is: 100.95048968532399 MSE for test is: 159.29909151162752
# MAE for training is: 6.787919906363566 MAE for test is: 7.919182589884087
# RMSE for training is: 10.047412088957234 RMSE for test is: 12.621374390755847
#
# *For model 790 settings are: -epochs: 100 -hidden neurons: 100 -hidden layers: 3 -activation: relu -regularization cost: 0.01 -random_state: 100
# Accuracy for training is: 0.8036273338329459 Accuracy for test is: 0.7681209661088964
# MSE for training is: 130.50326294168616 MSE for test is: 149.16426873818935
# MAE for training is: 7.995746077621752 MAE for test is: 8.434740662325643
# RMSE for training is: 11.423802472980972 RMSE for test is: 12.213282471890567

# %%
df_models = pd.DataFrame(models)
df_models.head(1)

# %%
df_models = df_models.set_index('Unnamed: 0').transpose()
print(df_models.shape)
df_models.head(5)

# %%
df_models.to_csv('../output/data/nn_models_trainsplit_v1.csv')

# %% [markdown]
# ## Filtering best models

# %%
df_models.acc_train.idxmax()
df_models.mse_train.idxmin()
df_models.mae_train.idxmin()
df_models.rmse_train.idxmin()
df_models.std_res_train.idxmin()
df_models.ia_train.idxmax()

# %%
df_models.acc_test.idxmax()
df_models.mse_test.idxmin()
df_models.mae_test.idxmin()
df_models.rmse_test.idxmin()
df_models.std_res_test.idxmin()
df_models.ia_test.idxmax()
