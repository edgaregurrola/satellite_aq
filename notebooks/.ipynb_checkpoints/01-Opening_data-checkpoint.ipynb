# %%
import pandas as pd
import numpy as np
import rasterio
from rasterio import features

# %%
src = rasterio.open(image_path)

# %%
array = src.read(1)
array.shape[0]
# Out:
# 881

# %%
from matplotlib import pyplot
pyplot.imshow(array, cmap='viridis')
pyplot.show()

# %%
len(array[0])
# Out:
# 2936

# %%
src.transform * (0, 0)
# Out:
# (-104.85767984567799, 20.22140136009954)

# %%
x = np.zeros((array.shape[0],array.shape[1]))
y = np.zeros((array.shape[0],array.shape[1]))
for r in range(src.height):
    for c in range(src.width):
        x[r,c] = src.xy(r, c)[0]
        y[r,c] = src.xy(r, c)[1]

# %%
df = pd.DataFrame(columns=['value','x','y'])
df['value'] = array.flatten().T
df['x'] = x.flatten().T
df['y'] = y.flatten().T

# %%
df.head(10)
# Out:
#       value           x          y
# 0  0.000045 -104.857231  20.221851
# 1  0.000045 -104.856332  20.221851
# 2  0.000045 -104.855434  20.221851
# 3  0.000045 -104.854536  20.221851
# 4  0.000045 -104.853637  20.221851
# 5  0.000045 -104.852739  20.221851
# 6  0.000045 -104.851841  20.221851
# 7  0.000045 -104.850942  20.221851
# 8  0.000064 -104.850044  20.221851
# 9  0.000064 -104.849146  20.221851

# %%
src_gdf = features.dataset_features(src)

# %%
shapes = features.shapes(src, mask=src)

# %%
shapes
# Out:
# <generator object shapes at 0x7f585c38e200>

# %%
import pprint

pprint.pprint(next(shapes))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-87-9dbef416aa52> in <module>
#       1 import pprint
#       2
# ----> 3 pprint.pprint(next(shapes))
#
# ~/anaconda3/envs/geo_env/lib/python3.8/site-packages/rasterio/features.py in shapes(source, mask, connectivity, transform)
#     125
#     126     transform = guard_transform(transform)
# --> 127     for s, v in _shapes(source, mask, connectivity, transform):
#     128         yield s, v
#     129
#
# rasterio/_features.pyx in _shapes()
#
# AttributeError: 'DatasetReader' object has no attribute 'dtype'

# %%
from osgeo import gdal,ogr

# %%
src_ds=gdal.Open(image_path) 
gt=src_ds.GetGeoTransform()
rb=src_ds.GetRasterBand(1)
gdal.UseExceptions()

# %%
src_ds
# Out:
# <osgeo.gdal.Dataset; proxy of <Swig Object of type 'GDALDatasetShadow *' at 0x7f586012ade0> >

# %%
import lidario as lio
    
# Create a Translator object which will take a tif file and return a np.array
translator = lio.Translator("geotiff", "np")
    
# Translate the tif file and get the np.array
point_cloud = translator.translate(image_path, band=1)

# %%
point_cloud[0]
# Out:
# array([-1.04857231e+02,  2.02218505e+01,  4.49679994e-05])
